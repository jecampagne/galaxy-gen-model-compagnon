# %%
# %pylab inline
import numpy as np

# %%
rcParams['font.size'] = 16

# %%
from numpy import genfromtxt

# %%
loss_info_A = genfromtxt('./loss_history_A.csv', delimiter=' ')
loss_info_B = genfromtxt('./loss_history_B.csv', delimiter=' ')

# %%
_, indices_A = np.unique(loss_info_A[:, 0], return_index=True)
_, indices_B = np.unique(loss_info_B[:, 0], return_index=True)

# %%
fig,ax=plt.subplots(1,1,figsize=(10,5))
ax.plot(loss_info_A[indices_A,0],loss_info_A[indices_A,1],label="A");
ax.plot(loss_info_B[indices_B,0],loss_info_B[indices_B,1],label="B",ls='--');
ax.set_xlabel("iter")
ax.set_ylabel("loss")
plt.grid()
#ax.set_yticks([0.5,0.6,0.7,0.8,0.9,1.0,1.1], minor=True)
ax.yaxis.grid(True, which='major')
ax.yaxis.grid(True, which='minor')
ax.set_ylim([0.2,1])
